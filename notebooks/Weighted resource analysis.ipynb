# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

# %%
data_path = "/home/s4k4yume/halite3/datasets/distance_vs_halite.npz"
data = np.load(data_path)

# %%
# Visualize halite
print(np.amax(data['halite']))
plt.imshow(data['halite'])
# Out:
# 950

# %%
# Visualize distance
print(np.amax(data['distance']))
plt.imshow(data['distance'])
# Out:
# 1.0

# %%
# Visualize penalized amount of halite
print(np.amax(data['penalized']))
fig = plt.figure
plt.imshow(data['penalized'])
pd.DataFrame(data['penalized']).plot()
# Out:
# 11648.0
